# %% [markdown]
# # Ejercicios - Sesión 001: Ciclos en Python
#
# Resuelve los siguientes ejercicios usando `for` y/o `while`.

# %% [markdown]
# ## Ejercicio 1
# Dada la lista `notas = [5.5, 6.1, 4.8, 6.7, 5.9]`, recórrela y muestra:
# 1. El promedio de las notas.
# 2. Cuántas notas son mayores o iguales a 6.0.
#
# **Objetivo:** usar acumuladores y contadores en ciclos.

# %%
notas = [5.5, 6.1, 4.8, 6.7, 5.9]
# Escribe tu solución aquí

# %% [markdown]
# ## Ejercicio 2
# Pide al usuario un número entero positivo `n` y muestra la suma de todos los números pares desde 1 hasta `n`.
#
# Ejemplo: si `n = 10`, la suma es `2 + 4 + 6 + 8 + 10 = 30`.
#
# **Objetivo:** combinar entrada de datos, validación simple y ciclos.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## Ejercicio 4 (Avanzado - lo explicaremos en clases)
# Construye un programa que lea números enteros uno por uno y termine solo cuando el usuario ingrese `0`.
# Al finalizar, debe mostrar:
# - Cantidad total de números ingresados (sin contar el 0).
# - Suma total.
# - Promedio.
# - Número mayor y número menor ingresados.
#
# **Este ejercicio lo desarrollarás guiado en la clase.**

# %%
# Espacio reservado para la resolución en clases
